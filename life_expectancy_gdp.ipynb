# %%
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv('all_data.csv')
print(data.head())
chile = data.loc[data['Country']=='Chile']
china = data.loc[data['Country']=='China']
germany = data.loc[data['Country']=='Germany']
mexico = data.loc[data['Country']=='Mexico']
usa = data.loc[data['Country']=='United States of America']
zimbabwe = data.loc[data['Country']=='Zimbabwe']

plt.plot(list(chile['Year']),list(chile['Life expectancy at birth (years)']))
plt.plot(list(china['Year']),list(china['Life expectancy at birth (years)']))
plt.plot(list(germany['Year']),list(germany['Life expectancy at birth (years)']))
plt.plot(list(mexico['Year']),list(mexico['Life expectancy at birth (years)']))
plt.plot(list(usa['Year']),list(usa['Life expectancy at birth (years)']))
plt.plot(list(zimbabwe['Year']),list(zimbabwe['Life expectancy at birth (years)']))
plt.title("Life expectancy over years by Country")
plt.legend(['Chile','China','Germany','Mexico','United States of America','Zimbabwe'],loc=2)
plt.show()
plt.close('all')
# Out:
#   Country  Year  Life expectancy at birth (years)           GDP
# 0   Chile  2000                              77.3  7.786093e+10
# 1   Chile  2001                              77.3  7.097992e+10
# 2   Chile  2002                              77.8  6.973681e+10
# 3   Chile  2003                              77.9  7.564346e+10
# 4   Chile  2004                              78.0  9.921039e+10

# %%
plt.plot(list(chile['Year']),list(chile['GDP']))
plt.plot(list(china['Year']),list(china['GDP']))
plt.plot(list(germany['Year']),list(germany['GDP']))
plt.plot(list(mexico['Year']),list(mexico['GDP']))
plt.plot(list(usa['Year']),list(usa['GDP']))
plt.plot(list(zimbabwe['Year']),list(zimbabwe['GDP']))
plt.title("GDP over years by Country")
plt.legend(['Chile','China','Germany','Mexico','United States of America','Zimbabwe'],loc=2)
plt.ylabel('GDP by USD$')
plt.show()
plt.close('all')

# %%
plt.scatter(data['GDP'],data['Life expectancy at birth (years)'])
plt.title('Life expectancy and GDP correlation')
plt.xlabel('GDP')
plt.ylabel('Life Expectancy')
plt.show()
plt.close('all')

# %%
plt.hist(data['Life expectancy at birth (years)'],bins=20)
plt.title('Life expectancy distribution')
plt.xlabel('Life expectancy')
plt.ylabel('Life Expectancy')
plt.show()
plt.close('all')
